# %%
import pandas as pd

# Create gender distribution data
data = {
    "Gender": ["Male", "Female"],
    "Population": [3850000000, 3700000000]
}

df = pd.DataFrame(data)

# Save as CSV
df.to_csv("gender_data.csv", index=False)

# Preview
df
# Out:
#    Gender  Population
# 0    Male  3850000000
# 1  Female  3700000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("gender_data.csv")

# Show the first few rows to confirm data loaded correctly
df.head()
# Out:
#    Gender  Population
# 0    Male  3850000000
# 1  Female  3700000000

# %%
df.columns
# Out:
# Index(['Gender', 'Population'], dtype='object')

# %%
#Gender-wise distribution
sns.countplot(x='Gender', data=df)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
#Create Dataset

import pandas as pd

# Sample dataset
data = {
    'Age Group': ['0–4', '0–4', '5–9', '5–9', '10–14', '10–14', '15–19', '15–19'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Population': [2500000, 2400000, 2600000, 2500000, 2550000, 2450000, 2480000, 2350000]
}

df = pd.DataFrame(data)

# Show the dataframe
df
# Out:
#   Age Group  Gender  Population
# 0       0–4    Male     2500000
# 1       0–4  Female     2400000
# 2       5–9    Male     2600000
# 3       5–9  Female     2500000
# 4     10–14    Male     2550000
# 5     10–14  Female     2450000
# 6     15–19    Male     2480000
# 7     15–19  Female     2350000

# %%
df.to_csv('age_gender_population.csv', index=False)

# %%
from google.colab import files
files.download('age_gender_population.csv')

# %%
df = pd.read_csv('age_gender_population.csv')
df.head()
# Out:
#   Age Group  Gender  Population
# 0       0–4    Male     2500000
# 1       0–4  Female     2400000
# 2       5–9    Male     2600000
# 3       5–9  Female     2500000
# 4     10–14    Male     2550000

# %%
df.groupby('Age Group')['Population'].sum().plot(kind='bar', color='orange', edgecolor='black')
plt.title("Total Population by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Population")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from google.colab import files

# Upload your CSV file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d001d675-d12e-4459-afce-2b872595ad65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d001d675-d12e-4459-afce-2b872595ad65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Read the CSV file
import pandas as pd

# Replace with the exact name of your file
df = pd.read_csv('histogram_age_dataset.csv')

# Check the first few rows
df.head()
# Out:
#    Gender  Age
# 0    Male   63
# 1  Female   20
# 2  Female   46
# 3  Female   52
# 4  Female   56

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(df['Age'], bins=10, color='lightgreen', edgecolor='black')
plt.title("Age Distribution (Histogram)")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset from GitHub
url = "https://raw.githubusercontent.com/datasets/population/master/data/population.csv"
df = pd.read_csv(url)

# Filter only for 2020 (or latest year)
df_2020 = df[df['Year'] == 2020]

# Sort top 10 countries
top10 = df_2020.sort_values(by='Value', ascending=False).head(10)

# Bar Chart
plt.figure(figsize=(10,6))
sns.barplot(x=top10['Country Name'], y=top10['Value'], palette='viridis')
plt.title("Top 10 Countries by Population (2020)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-1951994036.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top10['Country Name'], y=top10['Value'], palette='viridis')
